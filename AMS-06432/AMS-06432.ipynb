# %% [markdown]
#     ## Nama   : Fatimah Susilawati
#     ## Nim    : A12.2020.06432
#     ## Klmpok : A12.6501

# %% [markdown]
# # Eksperimen dan Pengumpulan Dataset
# ## Pemanggilan Library 1

# %%
import pandas as pd
import time
import tweepy
import numpy as np

# %%
def twitter_config():
    """
    Fungsi utilitas untuk mengkonfigurasi konsumsi file API Twitter dengan␣
    ,!kunci yang disediakan.
    """
    # Otentikasi dan akses menggunakan kunci:
    auth = tweepy.OAuthHandler("SbtGvRsiIy1nDmCPVKTgpWMtK", "RA5iiToE8iqHOkPwQLhS1FQsAGGIKtFKwA5YEYnC4oHuXSyUrO")
    auth.set_access_token("1576789174799446016-wD1KiB28mnVdYWaxquJNuvIdfB6JPT", "1Pu9xNobL0NMxiAjCWViJIHlEWrYQM2cD1aGu9urkwYGY")
    # Kembalikan akses ke API:
    api = tweepy.API(auth)
    try:
        api.verify_credentials()
        print("Authentication OK")
    except:
        print("Error during authentication")
    return api

# %%
# buat extractor object
extractor = twitter_config()
# Out:
# Authentication OK

# %% [markdown]
# # Ambil Tweet dari Username
# ## Username yang saya gunakan yakni @detikcom

# %%
tweets = extractor.user_timeline(screen_name="detikcom", count=1000)
print("Tweets terambil: {}.\n".format(len(tweets)))

print("100 tweet teratas:\n")
for tweet in tweets[:100]:
    print(tweet.text)
    print()
# Out:
# Tweets terambil: 200.
#
# 100 tweet teratas:
#
# Artis sekaligus Youtuber Deddy Corbuzier lagi berbunga-bunga. Sebab dua drifter Alpha Rules Drift Team naik podium… https://t.co/64ZCsJSUpd
#
# Top Topan merupakan lagu pop berbahasa Jawa yang mengusung tema cinta, khususnya tentang patah hati. Berikut cerita… https://t.co/gBsZbka9fu
#
# TGIPF merekomendasikan setiap klub sepakbola memiliki stadion pribadi untuk berlaga. Hal ini dikatakan oleh anggota… https://t.co/XoqwEiDvFN
#
# Istri Gubernur Jawa Barat Ridwan Kamil, Atalia Praratya berhasil lulus Program Doktor Ilmu Komunikasi Unpad. Teliti… https://t.co/B8aJnFZleq
#
# Selain dijadikan untuk konten YouTube, rumah kosong di Bandung ternyata jadi sasaran maling. Ratusan barang di loka… https://t.co/7KfUcJ2E9Z
#
# Seorang balita yang menjadi satu-satunya anak yang selamat dalam pembantaian massal di Thailand, tengah tertidur di… https://t.co/GGQtqFxzrk
#
# Chee Hoi Lan, seorang wanita Tionghoa menerima penghargaan Ikon Ibu Sejati-Keluarga Malaysia karena membesarkan ana… https://t.co/y8NmptcUMx
#
# Seorang wanita bernama Brooke Martin jadi viral di TikTok karena penampilannya rahang yang kotak. Dia di-bully miri… https://t.co/5wcBw3qJeV
#
# Mengerikan dan mencekam adalah kalimat yang tepat menggambarkan suasana di pintu 13 Stadion Kanjuruhan usai laga Ar… https://t.co/OWhoSUDPzR
#
# Aniesmengatakan dirinya rutin bertemu dengan tokoh dan pemuka agama di Jakarta jelang jabatannya berakhir. Dia meng… https://t.co/VFkrw0YvQU
#
# Banjir di kawasan Bandung Selatan diklaim telah jauh berkurang. Hal itu berkat beberapa upaya yang dilakukan pemeri… https://t.co/JnW8hVC16V
#
# Ujian bagi The Reds belum berhenti sampai di sini. Akhir pekan ini, Liverpool bakal diuji oleh Man CIty yang bakal… https://t.co/YO1epF1Rbj
#
# Petugas Damkar sektor Jatinegara mengevakuasi seorang bayi saat banjir melanda kawasan Bidara Cina, Jakarta Timur.… https://t.co/tRZzi8rZNf
#
# Sosok Pangeran Aria Suria Atmadja dikenang dalam bentuk Monumen Lingga yang kini menjadi lambang Kabupaten Sumedang… https://t.co/CsK6sULGUT
#
# Sebelum dipentaskan di TIM akhir pekan lalu, panggung opera Majapahit: Gayatri terlebih dahulu memukau di Edinburgh… https://t.co/XzF9kJdJm6
#
# Komisi Nasional Hak Asasi Manusia mendapatkan temuan adanya gas air mata kedaluwarsa yang ditembakan saat tragedi K… https://t.co/pnajGSSA2Q
#
# Peristiwa itu diketahui terjadi pada Sabtu (8/10), sekitar pukul 16.19 WIB. Polisi masih menyelidikinya. https://t.co/rl9CoESN05
#
# Zelensky menuduh Rusia ingin membinasakan dan menghapus Ukraina dari muka bumi setelah rentetan serangan rudal meng… https://t.co/lRg5n1BbaM
#
# Polri telah menetapkan enam tersangka terkait Tragedi Kanjuruhan. Keenamnya dijadwalkan akan diperiksa besok di Pol… https://t.co/MiF8IfyPhG

# %% [markdown]
# ## Memasukkan ke dataframe pandas

# %%
# Membuat kerangka data menggunakan sintaks berikut
dataset = pd.DataFrame(data = [tweet.text for tweet in tweets], columns = ['Tweets'])

# Tampilan kerangka data
display(dataset.head(100))
# Out:
#                                                Tweets
# 0   Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1   Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2   TGIPF merekomendasikan setiap klub sepakbola m...
# 3   Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4   Selain dijadikan untuk konten YouTube, rumah k...
# ..                                                ...
# 95  Sebelum dipentaskan di TIM akhir pekan lalu, p...
# 96  Komisi Nasional Hak Asasi Manusia mendapatkan ...
# 97  Peristiwa itu diketahui terjadi pada Sabtu (8/...
# 98  Zelensky menuduh Rusia ingin membinasakan dan ...
# 99  Polri telah menetapkan enam tersangka terkait ...
#
# [100 rows x 1 columns]

# %%
dataset.to_csv('dataset_detikcom.csv')

# %% [markdown]
# ## Cleaning Word
# ## Import Library untuk Cleaning Word

# %%
import pandas as pd
import re
import string
import time
from copy import deepcopy

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('dataset_detikcom.csv')

df.head(10)
# Out:
#    Unnamed: 0                                             Tweets
# 0           0  Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1           1  Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2           2  TGIPF merekomendasikan setiap klub sepakbola m...
# 3           3  Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4           4  Selain dijadikan untuk konten YouTube, rumah k...
# 5           5  Seorang balita yang menjadi satu-satunya anak ...
# 6           6  Chee Hoi Lan, seorang wanita Tionghoa menerima...
# 7           7  Seorang wanita bernama Brooke Martin jadi vira...
# 8           8  Mengerikan dan mencekam adalah kalimat yang te...
# 9           9  Aniesmengatakan dirinya rutin bertemu dengan t...

# %%
df
# Out:
#      Unnamed: 0                                             Tweets
# 0             0  Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1             1  Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2             2  TGIPF merekomendasikan setiap klub sepakbola m...
# 3             3  Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4             4  Selain dijadikan untuk konten YouTube, rumah k...
# ..          ...                                                ...
# 195         195  Performa gila Erling Haaland bersama Mancheste...
# 196         196  Seorang wanita 25 tahun, Becca Butcher menceri...
# 197         197  Serangan rudal menghantam banyak kota di Ukrai...
# 198         198  #Foto Separator atau median jalan di Jalan Mar...
# 199         199  Sejak kenaikan harga menjadi Rp 10.000 per lit...
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# ## Preprocessing Dataset
# #### Yang yang harus dilakukan yaitu instalasi modul ekhprasis

# %%
# !pip install ekphrasis
# Out:
# Collecting ekphrasis
#   Downloading ekphrasis-0.5.4-py3-none-any.whl (83 kB)
# Requirement already satisfied: nltk in c:\users\asus\anaconda3\lib\site-packages (from ekphrasis) (3.7)
# Requirement already satisfied: matplotlib in c:\users\asus\anaconda3\lib\site-packages (from ekphrasis) (3.5.1)
# Requirement already satisfied: ujson in c:\users\asus\anaconda3\lib\site-packages (from ekphrasis) (5.1.0)
# Requirement already satisfied: numpy in c:\users\asus\anaconda3\lib\site-packages (from ekphrasis) (1.21.5)
# Requirement already satisfied: colorama in c:\users\asus\anaconda3\lib\site-packages (from ekphrasis) (0.4.4)
# Requirement already satisfied: tqdm in c:\users\asus\anaconda3\lib\site-packages (from ekphrasis) (4.64.0)
# Collecting termcolor
#   Downloading termcolor-2.0.1-py3-none-any.whl (5.4 kB)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in c:\users\asus\anaconda3\lib\site-packages (from ftfy->ekphrasis) (0.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\asus\anaconda3\lib\site-packages (from matplotlib->ekphrasis) (1.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->ekphrasis) (1.16.0)
# Requirement already satisfied: joblib in c:\users\asus\anaconda3\lib\site-packages (from nltk->ekphrasis) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\asus\anaconda3\lib\site-packages (from nltk->ekphrasis) (2022.3.15)
# Requirement already satisfied: click in c:\users\asus\anaconda3\lib\site-packages (from nltk->ekphrasis) (8.0.4)
# Installing collected packages: termcolor, ftfy, ekphrasis
# Successfully installed ekphrasis-0.5.4 ftfy-6.1.1 termcolor-2.0.1

# %%
from ekphrasis.classes.preprocessor import TextPreProcessor
from ekphrasis.classes.tokenizer import SocialTokenizer
from ekphrasis.dicts.emoticons import emoticons

text_processor = TextPreProcessor(
    # terms that will be normalized
    normalize=['email', 'percent', 'money', 'phone', 'user',
        'time', 'date', 'number'],
    # terms that will be annotated
    #annotate={"hashtag", "allcaps", "elongated", "repeated",'emphasis', 'censored'},
    annotate={"hashtag"},
    fix_html=True,  # fix HTML tokens
    
    # corpus from which the word statistics are going to be used 
    # for word segmentation 
    segmenter="twitter", 
    
    # corpus from which the word statistics are going to be used 
    # for spell correction
    corrector="twitter", 
    
    unpack_hashtags=True,  # perform word segmentation on hashtags
    unpack_contractions=True,  # Unpack contractions (can't -> can not)
    spell_correct_elong=False,  # spell correction for elongated words
    
    # select a tokenizer. You can use SocialTokenizer, or pass your own
    # the tokenizer, should take as input a string and return a list of tokens
    tokenizer=SocialTokenizer(lowercase=True).tokenize,
    
    # list of dictionaries, for replacing tokens extracted from the text,
    # with other expressions. You can pass more than one dictionaries.
    dicts=[emoticons]
)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\ekphrasis\classes\tokenizer.py:225: FutureWarning: Possible nested set at position 2190
#   self.tok = re.compile(r"({})".format("|".join(pipeline)))
# Word statistics files not found!
# Downloading... done!
# Unpacking... done!
# Reading twitter - 1grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\ASUS\.ekphrasis\stats\twitter\counts_1grams.txt
# Reading twitter - 2grams ...
# generating cache file for faster loading...
# reading ngrams C:\Users\ASUS\.ekphrasis\stats\twitter\counts_2grams.txt
# C:\Users\ASUS\anaconda3\lib\site-packages\ekphrasis\classes\exmanager.py:14: FutureWarning: Possible nested set at position 42
#   regexes = {k.lower(): re.compile(self.expressions[k]) for k, v in
# Reading twitter - 1grams ...

# %%
# panggil ekphrasis

def bersih_data(text):
    return " ".join(text_processor.pre_process_doc(text))

# %%
# fungsi dari AMS 01-03. silakan cek bagaimana saya merubah menjadi fungsi

def non_ascii(text):
    return text.encode('ascii', 'replace').decode('ascii')

def remove_space(text):
    return " ".join(text.split())

def remove_emoji(text):
    return ' '.join(re.sub("([x#][A-Za-z0-9]+)"," ", text).split())

def remove_tab(text):
    return text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")

def remove_tab2(text):
    return re.sub('\s+',' ',text)

def remove_rt(text):
    return text.replace('RT'," ")

def remove_mention(text):
    return ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())

def remove_incomplete_url(text):
    return text.replace("http://", " ").replace("https://", " ")

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def change_stripe(text):
    return text.replace('-'," ")

def lower(text):
    return text.lower()

def remove_single_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

def remove_excessive_dot(text):
    return text.replace('..'," ")

def lower(text):
    return text.lower()

def remove_whitespace_LT(text):
    return text.strip()

def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

def remove_punctuation(text):
    remove = string.punctuation
    remove = remove.replace("_", "") # don't remove hyphens
    pattern = r"[{}]".format(remove) # create the pattern
    return re.sub(pattern, "", text)

# %%
# hapus untuk <>
def remove_number_eks(text):
    return text.replace('<number>'," ")

def remove_angka(text):
    return re.sub(r"\d+", "", text) 

def remove_URL_eks(text):
    return text.replace('URL'," ").replace('url'," ")

def space_punctuation(text):
    return re.sub('(?<! )(?=[.,!?()])|(?<=[.,!?()])(?! )', r' ', text)

# %% [markdown]
# ## Mulai proses pembersihan

# %%
i = 0
final_string = []
s = ""
for text in df['Tweets'].values:
    filteredSentence = []
    EachReviewText = ""
    proc = remove_rt(text)
    proc = lower(proc)
    proc = change_stripe(proc)
    proc = remove_emoji(proc)
    proc = remove_tab(proc)
    proc = remove_tab2(proc)
    proc = non_ascii(proc)
    proc = remove_incomplete_url(proc)
    proc = remove_excessive_dot(proc)
    proc = remove_whitespace_LT(proc)
    proc = remove_whitespace_multiple(proc)
    proc = remove_single_char(proc)
    proc = space_punctuation(proc)
    proc = remove_punctuation(proc)
    proc = remove_space(proc)
    proc = bersih_data(proc)
    proc = remove_number_eks(proc)
    proc = remove_angka(proc) 
    proc = remove_URL_eks(proc)
    EachReviewText = proc
    final_string.append(EachReviewText)

# %%
df["step01"] = final_string

# %%
df.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1           1  Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2           2  TGIPF merekomendasikan setiap klub sepakbola m...
# 3           3  Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4           4  Selain dijadikan untuk konten YouTube, rumah k...
# 5           5  Seorang balita yang menjadi satu-satunya anak ...
# 6           6  Chee Hoi Lan, seorang wanita Tionghoa menerima...
# 7           7  Seorang wanita bernama Brooke Martin jadi vira...
# 8           8  Mengerikan dan mencekam adalah kalimat yang te...
# 9           9  Aniesmengatakan dirinya rutin bertemu dengan t...
#
#                                               step01
# 0  artis sekaligus youtuber deddy corbuzier lagi ...
# 1  top topan merupakan lagu pop berbahasa jawa ya...
# 2  tgipf merekomendasikan setiap klub sepakbola m...
# 3  istri gubernur jawa barat ridwan kamil atalia ...
# 4  selain dijadikan untuk konten youtube rumah ko...
# 5  seorang balita yang menjadi satu satunya anak ...
# 6  chee hoi lan seorang wanita tionghoa menerima ...
# 7  seorang wanita bernama brooke martin jadi vira...
# 8  mengerikan dan mencekam adalah kalimat yang te...
# 9  aniesmengatakan dirinya rutin bertemu dengan t...

# %% [markdown]
# ## Hapus data kosong

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_hapus = df[~df['step01'].str.contains(" ")]

# %%
df_hapus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      int64
#  1   Tweets      0 non-null      object
#  2   step01      0 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 0.0+ bytes

# %%
df_hapus.head(10)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Tweets, step01]
# Index: []

# %%
df_new = df[~df.isin(df_hapus)].dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   Tweets      200 non-null    object
#  2   step01      200 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_new
# Out:
#      Unnamed: 0                                             Tweets  \
# 0             0  Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1             1  Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2             2  TGIPF merekomendasikan setiap klub sepakbola m...
# 3             3  Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4             4  Selain dijadikan untuk konten YouTube, rumah k...
# ..          ...                                                ...
# 195         195  Performa gila Erling Haaland bersama Mancheste...
# 196         196  Seorang wanita 25 tahun, Becca Butcher menceri...
# 197         197  Serangan rudal menghantam banyak kota di Ukrai...
# 198         198  #Foto Separator atau median jalan di Jalan Mar...
# 199         199  Sejak kenaikan harga menjadi Rp 10.000 per lit...
#
#                                                 step01
# 0    artis sekaligus youtuber deddy corbuzier lagi ...
# 1    top topan merupakan lagu pop berbahasa jawa ya...
# 2    tgipf merekomendasikan setiap klub sepakbola m...
# 3    istri gubernur jawa barat ridwan kamil atalia ...
# 4    selain dijadikan untuk konten youtube rumah ko...
# ..                                                 ...
# 195  performa gila erling haaland bersama mancheste...
# 196  seorang wanita   tahun becca butcher mencerita...
# 197  serangan rudal menghantam banyak kota di ukrai...
# 198  separator atau median jalan di jalan margonda ...
# 199  sejak kenaikan harga menjadi rp     per liter ...
#
# [200 rows x 3 columns]

# %% [markdown]
# ## Normalisasi kata slang menjadi baku

# %%
# token
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
def word_tokenize_wrapper(text):
  return word_tokenize(text)

# %%
df_new['tokens'] = df["step01"].apply(word_tokenize_wrapper)

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1           1  Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2           2  TGIPF merekomendasikan setiap klub sepakbola m...
# 3           3  Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4           4  Selain dijadikan untuk konten YouTube, rumah k...
# 5           5  Seorang balita yang menjadi satu-satunya anak ...
# 6           6  Chee Hoi Lan, seorang wanita Tionghoa menerima...
# 7           7  Seorang wanita bernama Brooke Martin jadi vira...
# 8           8  Mengerikan dan mencekam adalah kalimat yang te...
# 9           9  Aniesmengatakan dirinya rutin bertemu dengan t...
#
#                                               step01  \
# 0  artis sekaligus youtuber deddy corbuzier lagi ...
# 1  top topan merupakan lagu pop berbahasa jawa ya...
# 2  tgipf merekomendasikan setiap klub sepakbola m...
# 3  istri gubernur jawa barat ridwan kamil atalia ...
# 4  selain dijadikan untuk konten youtube rumah ko...
# 5  seorang balita yang menjadi satu satunya anak ...
# 6  chee hoi lan seorang wanita tionghoa menerima ...
# 7  seorang wanita bernama brooke martin jadi vira...
# 8  mengerikan dan mencekam adalah kalimat yang te...
# 9  aniesmengatakan dirinya rutin bertemu dengan t...
#
#                                               tokens
# 0  [artis, sekaligus, youtuber, deddy, corbuzier,...
# 1  [top, topan, merupakan, lagu, pop, berbahasa, ...
# 2  [tgipf, merekomendasikan, setiap, klub, sepakb...
# 3  [istri, gubernur, jawa, barat, ridwan, kamil, ...
# 4  [selain, dijadikan, untuk, konten, youtube, ru...
# 5  [seorang, balita, yang, menjadi, satu, satunya...
# 6  [chee, hoi, lan, seorang, wanita, tionghoa, me...
# 7  [seorang, wanita, bernama, brooke, martin, jad...
# 8  [mengerikan, dan, mencekam, adalah, kalimat, y...
# 9  [aniesmengatakan, dirinya, rutin, bertemu, den...

# %%
normalized_word = pd.read_csv('kamus_clean.csv')

# %%
normalized_word_dict = {}

for index, row in normalized_word.iterrows():
    if row[0] not in normalized_word_dict:
        normalized_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalized_word_dict[term] if term in normalized_word_dict else term for term in document]

# %%
df_new['final_tokens'] = df_new['tokens'].apply(normalized_term)

# %%
i=0
final_string_tokens = []
for text in df_new['final_tokens'].values:
    EachReviewText = ""
    EachReviewText = ' '.join(text)
    final_string_tokens.append(EachReviewText)

# %%
df_new["step02"] = final_string_tokens

# %%
df_new.head(10)
# Out:
#    Unnamed: 0                                             Tweets  \
# 0           0  Artis sekaligus Youtuber Deddy Corbuzier lagi ...
# 1           1  Top Topan merupakan lagu pop berbahasa Jawa ya...
# 2           2  TGIPF merekomendasikan setiap klub sepakbola m...
# 3           3  Istri Gubernur Jawa Barat Ridwan Kamil, Atalia...
# 4           4  Selain dijadikan untuk konten YouTube, rumah k...
# 5           5  Seorang balita yang menjadi satu-satunya anak ...
# 6           6  Chee Hoi Lan, seorang wanita Tionghoa menerima...
# 7           7  Seorang wanita bernama Brooke Martin jadi vira...
# 8           8  Mengerikan dan mencekam adalah kalimat yang te...
# 9           9  Aniesmengatakan dirinya rutin bertemu dengan t...
#
#                                               step01  \
# 0  artis sekaligus youtuber deddy corbuzier lagi ...
# 1  top topan merupakan lagu pop berbahasa jawa ya...
# 2  tgipf merekomendasikan setiap klub sepakbola m...
# 3  istri gubernur jawa barat ridwan kamil atalia ...
# 4  selain dijadikan untuk konten youtube rumah ko...
# 5  seorang balita yang menjadi satu satunya anak ...
# 6  chee hoi lan seorang wanita tionghoa menerima ...
# 7  seorang wanita bernama brooke martin jadi vira...
# 8  mengerikan dan mencekam adalah kalimat yang te...
# 9  aniesmengatakan dirinya rutin bertemu dengan t...
#
#                                               tokens  \
# 0  [artis, sekaligus, youtuber, deddy, corbuzier,...
# 1  [top, topan, merupakan, lagu, pop, berbahasa, ...
# 2  [tgipf, merekomendasikan, setiap, klub, sepakb...
# 3  [istri, gubernur, jawa, barat, ridwan, kamil, ...
# 4  [selain, dijadikan, untuk, konten, youtube, ru...
# 5  [seorang, balita, yang, menjadi, satu, satunya...
# 6  [chee, hoi, lan, seorang, wanita, tionghoa, me...
# 7  [seorang, wanita, bernama, brooke, martin, jad...
# 8  [mengerikan, dan, mencekam, adalah, kalimat, y...
# 9  [aniesmengatakan, dirinya, rutin, bertemu, den...
#
#                                         final_tokens  \
# 0  [artis, sekaligus, youtuber, deddy, corbuzier,...
# 1  [top, topan, merupakan, lagu, pop, berbahasa, ...
# 2  [tgipf, merekomendasikan, setiap, klub, sepakb...
# 3  [istri, gubernur, jawa, barat, ridwan, kamil, ...
# 4  [selain, dijadikan, untuk, konten, youtube, ru...
# 5  [seorang, balita, yang, menjadi, satu, satunya...
# 6  [chee, hoi, lan, seorang, wanita, tionghoa, me...
# 7  [seorang, wanita, bernama, brooke, martin, jad...
# 8  [mengerikan, dan, mencekam, adalah, kalimat, y...
# 9  [aniesmengatakan, dirinya, rutin, bertemu, den...
#
#                                               step02
# 0  artis sekaligus youtuber deddy corbuzier lagi ...
# 1  top topan merupakan lagu pop berbahasa jawa ya...
# 2  tgipf merekomendasikan setiap klub sepakbola m...
# 3  istri gubernur jawa barat ridwan kamil atalia ...
# 4  selain dijadikan untuk konten youtube rumah ko...
# 5  seorang balita yang menjadi satu satunya anak ...
# 6  chee hoi lan seorang wanita tionghoa menerima ...
# 7  seorang wanita bernama brooke martin jadi vira...
# 8  mengerikan dan mencekam adalah kalimat yang te...
# 9  aniesmengatakan dirinya rutin bertemu dengan t...

# %% [markdown]
# ## Simpan Clean Dataset

# %%
df_new.to_csv('clean_dataset_detikcom')
